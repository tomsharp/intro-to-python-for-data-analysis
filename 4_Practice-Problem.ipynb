# %% [markdown]
# Imagine you are working for HUD. You are given the task to clean and visualize some of their data for Boston Housing Prices. However, the data you received is not clean and also outdated. The client is asking you to find some insights in this data by COB.

# %% [markdown]
# Given that you are a savvy Analytics practitioner, you know that there is a process for processing data. That process is simplified below.

# %%
from IPython.display import Image; Image(filename='img/analytics-process.png')

# %% [markdown]
# Provide HUD with an executive-level report on the data. To do this, you need to read in the data, pre-process it, write the cleaned data to a database, read the data back in, and provide visualizations and tables of the data.
# <br>
# A few requirements from the client include:
# 1. This data is from 1980. Provide an estimate of housing prices in 2020 using a simple 4x multiple of the 'cmdev' column
# 2. HUD is not concerned with houses along the river, as those are usually inflated prices and not of use to their decision making
# 3. One metric that HUD absolutely needs is to find the average price per town (hint: use groupby)
# 4. One of the Directors that you work closely with is in charge of providing new programs to neighborhoods with significant populations over 50. Provide some recommendations and insights

# %% [markdown]
# 1. Read in the data file from CSV

# %% [markdown]
# 2. Clean the data. write to the DB

# %% [markdown]
# 3. Read in the data from the DB, and provide a few visualizations of the data

# %% [markdown]
# 4. Provide an executive-level report using some of the visualization you produced and any other information (pivot tables, etc.) including an explanation of your findings
